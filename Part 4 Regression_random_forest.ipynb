# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('BACE1_bioactivity data_pubchem_figerprints.csv')

# %%
df
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0            1.0         1.0         1.0  ...           0.0           0.0  6.384050
# 1            1.0         1.0         1.0  ...           0.0           0.0  8.698970
# 2            1.0         1.0         1.0  ...           0.0           0.0  6.337242
# 3            1.0         1.0         1.0  ...           0.0           0.0  4.468521
# 4            1.0         1.0         1.0  ...           0.0           0.0  7.698970
# ...          ...         ...         ...  ...           ...           ...       ...
# 7198         1.0         1.0         0.0  ...           0.0           0.0  6.154902
# 7199         1.0         1.0         1.0  ...           0.0           0.0  6.221849
# 7200         1.0         1.0         1.0  ...           0.0           0.0  6.602060
# 7201         1.0         1.0         0.0  ...           0.0           0.0  4.707744
# 7202         NaN         NaN         NaN  ...           NaN           NaN  6.221849
#
# [7203 rows x 882 columns]

# %% [markdown]
# Input features
# The BACE1 data contains 881 input features and 1 output variable(pIC50)

# %%
#  input features
X = df.drop('pIC50', axis = 1)
X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0            1.0         1.0  ...           0.0           0.0
# 1            1.0         1.0  ...           0.0           0.0
# 2            1.0         1.0  ...           0.0           0.0
# 3            1.0         1.0  ...           0.0           0.0
# 4            1.0         1.0  ...           0.0           0.0
# ...          ...         ...  ...           ...           ...
# 7198         1.0         1.0  ...           0.0           0.0
# 7199         1.0         1.0  ...           0.0           0.0
# 7200         1.0         1.0  ...           0.0           0.0
# 7201         1.0         1.0  ...           0.0           0.0
# 7202         NaN         NaN  ...           NaN           NaN
#
# [7203 rows x 881 columns]

# %%
Y = df.pIC50
Y
# Out:
# 0       6.384050
# 1       8.698970
# 2       6.337242
# 3       4.468521
# 4       7.698970
#           ...
# 7198    6.154902
# 7199    6.221849
# 7200    6.602060
# 7201    4.707744
# 7202    6.221849
# Name: pIC50, Length: 7203, dtype: float64

# %%
X.shape
# Out:
# (7203, 881)

# %%
Y.shape
# Out:
# (7203,)

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))
X = selection.fit_transform(X)

# %%
X.shape
# Out:
# (7203, 164)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size =0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((5762, 164), (5762,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((1441, 164), (1441,))

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2 = model.score(X_test, Y_test)
r2
# Out:
# 0.5574185813093697

# %%
Y_pred = model.predict(X_test)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(x=Y_test, y=Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
